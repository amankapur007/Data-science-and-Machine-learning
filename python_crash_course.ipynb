# %%
1+1

# %%
1

# %%
1/2

# %%
2 ** 4

# %%
2 + 3 * 5 + 5

# %%
(2 + 3) * (5 + 5)

# %%
5 % 2

# %%
x = 2
y = 3

# %%
x + y

# %%
name_of_var =12

# %%
# Strings

# %%
' single quote'

# %%
"Double Quotes"

# %%
"I can't go'"

# %%
#Printing String

# %%
x = 'hello'

# %%
x

# %%
print(x)

# %%
num = 12 
name= 'Sam'

# %%
print('My number is {} and name is {}'.format(num,name))

# %%
print('My number is {one} and name is {two}'.format(one=num,two=name))

# %%
s='hello'

# %%
s[0]

# %%
s[-1]

# %%
s='abcdefghijk'

# %%
s[0]

# %%
s[0:]

# %%
s[:3]

# %%
s[0:3]

# %%
s[0::2]

# %%
#List

# %%
[1,2,3,4,5,6]

# %%
['a','b','c']

# %%
my_list=['a','b','c']

# %%
my_list.append('d')

# %%
my_list

# %%
my_list[0:2]

# %%
my_list[0]='NEW'

# %%
my_list

# %%
nest=[1,2,[3,4]]

# %%
nest[2][1]

# %%
nest = [1,2,3,[4,5,['target']]]

# %%
nest[3][2][0]

# %%
d={'key1':'value','key2':123}

# %%
d

# %%
d['key1']

# %%
d['key2']

# %%
d={'k1':{'innerkey':[1,2,3]}}

# %%
d['k1']['innerkey'][1]

# %%
True

# %%
False

# %%
#Tupples

# %%
t= (1,2,3)

# %%
t[0]

# %%
#Are immutable t[0] = 'NEW' --> will give error

# %%
#Sets

# %%
s = {1,2,3,1}

# %%
s

# %%
s = set([1,2,3,1,2,3,4,1])

# %%
s

# %%
s.add(5)

# %%
s

# %%
s.add(2)

# %%
s

# %%
#Comparision operator

# %%
1>2

# %%
2==2

# %%
1>=2

# %%
1<=1

# %%
1!=2

# %%
'hi' == 'bye'

# %%
#Logical Operator

# %%
1<2 and 3>2

# %%
1<2 and 2>3

# %%
1<2 or 2>3

# %%
True and True

# %%
True and False

# %%
True or False

# %%
#If elif and else

# %%
if 1<2 :
    print('Yep!')

# %%
if True:
    x = 2+2

# %%
x

# %%
if 1 == 2:
    print('First')
else:
    print('Last')

# %%
if 1==2:
    print("first")
elif 4==4:
    print('middle')
else:
    print('last')

# %%
seq = [1,2,3,4]

# %%
for item in seq:
    print(item)

# %%
for item in seq:
    print('hello')

# %%
i=1
while i<5:
    print("Value of {i} ".format(i=i))
    i=i+1

# %%
for x in range(1,11):
    print(x)

# %%
for x in range(1,11,2):
    print(x)

# %%
list(range(0,5))

# %%
list(range(10))

# %%
#list comprehension

# %%
x = [1,2,3,4]

# %%
out = []

for item in x:
    out.append(item**2)

# %%
out

# %%
out = [item**2 for item in x] #-->List comprehension

# %%
out

# %%
#Functions

# %%
def fun():
    print('Hello function')

# %%
fun()

# %%
def fun_par(param1):
    print('{}'.format(param1))

# %%
fun_par('Hello function')

# %%
def func(name='learners'):
    print('Hello {} '.format(name))

# %%
func()

# %%
func('John')

# %%
def sqr(num):
    return num**2

# %%
output = sqr(4)

# %%
output

# %%
#Map and Filter

# %%
def times2(var):
    return var*2

# %%
times2(5)

# %%
seq = [1,2,3,4,5]

# %%
#map()
map(times2,seq)

# %%
list(map(times2,seq))

# %%
#Easier way -->lambda

# %%
def times2(var):return var*2 # lambda remove def and return

# %%
t = lambda var:var*2

# %%
t(6)

# %%
list(map(lambda var:var*2,seq))

# %%
#filter()

# %%
list(filter(lambda var:var%2==0,seq)) # i have lambda with filter we can do that with function too

# %%
#Methods

# %%
s = 'hello my name is Sam'

# %%
s.capitalize()

# %%
s.casefold()

# %%
s.lower()

# %%
s.upper()

# %%
s.split(' ') # or s.split()

# %%
tweet = 'Go Sports !#Sports'

# %%
tweet.split('#')

# %%
d = {'k1':1,'k2':2}

# %%
d.keys()

# %%
d.values()

# %%
d.items()

# %%
list = [1,2,3]

# %%
list.pop()

# %%
list

# %%
list.pop(1) #-->index

# %%
list

# %%
list.append(5)

# %%
list

# %%
'x' in 'christmas'

# %%
'x' in 'x-men'

# %%
list = ['a','b','c']

# %%
'x' in list

# %%
'a' in list

# %%
#tuple and packaging

# %%
x = [(1,2),(3,4),(5,6)]

# %%
for item in x:
    print(item)

# %%
for (a,b) in x:
    print('a {}'.format(a))
    print('b {}'.format(b))

# %%
# Few Exercise (!gnore it)

# %%
7**4

# %%
s ="Hi this is sam"
s.split()

# %%
planet="Earth"
diameter=12742
print(f'The diamter of {planet} is {diameter} kilometer')
